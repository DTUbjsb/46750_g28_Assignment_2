# %%
import os
from pathlib import Path
from gurobipy import Model, GRB
from data_loader import load_prices, load_storage, load_efficiency, load_plant_capacity, load_demand
import pandas as pd

# Data Loading from data folder in the parent directory
current_dir = Path().resolve()
data_folder = os.path.join(current_dir.parent, "data")
fuel_prices_file = os.path.join(data_folder, "fuel_prices.csv")             # Price in EUR/tonne (coal,oil) or EUR/m3 (gas)
storage_file = os.path.join(data_folder, "storage.csv")                     # Max storage in tonnes/m3
efficiency_file = os.path.join(data_folder, "efficiency.csv")               # efficiency of MWh th to MWh el
plant_file = os.path.join(data_folder, "plant_capacity.csv")                # Plant capacity in MWh/month
demand_file = os.path.join(data_folder, "electricity_demand.csv")           # Monthly demand in MWh

start_date = "2020-01"
end_date = "2022-12"
fuels = ["coal", "oil", "gas"]
zone = 'DK_1'  # Specify the zone for demand data
resample_method = 'M' # Monthly resampling 

try:
    fuel_prices_df = load_prices(fuel_prices_file, start_date, end_date, resample_method= resample_method)
    storage = load_storage(storage_file)
    efficiency = load_efficiency(efficiency_file)
    plant_capacity = load_plant_capacity(plant_file)
    demand_df = load_demand(demand_file, start_date, end_date, resample_method= resample_method ,zone=zone ,supply_factor=0.6)
except Exception as e:
    raise RuntimeError(f"Error loading data: {e}")

# periods as Month PeriodIndex (so days_in_month works)
periods = demand_df.index.to_period('M')

print( periods)


# Forloop over each timestep and saving results in df results
results = pd.DataFrame(columns=['Month', 'Cost_EUR','Accumulated_Cost' , 'Coal_Bought', 'Oil_Bought', 'Gas_Bought',
                                   'Coal_Generated', 'Oil_Generated', 'Gas_Generated'])

for t in range(len(demand_df)):
    print(f"Time step: {t}, Date: {demand_df.index[t]}")
    
    # Model Initialization
    m = Model("Fuel_Procurement_OneMonth")

    # Decision Variables
    x = {fuel: m.addVar(lb=0, ub=storage[fuel], name=f"buy_{fuel}") for fuel in fuel_prices_df.columns if fuel in fuels}
    #y = {fuel: m.addVar(lb=0, ub=plant_capacity[fuel], name=f"gen_{fuel}") for fuel in fuel_prices_df.columns if fuel in fuels}    
    
    y = {}
    for fuel in fuels:
                            
            hours_in_month = periods[t].days_in_month * 24

            print(f"Hours in month {periods[t]}: {hours_in_month}")
            # plant_capacity[fuel] is MW -> convert to MWh/month
            monthly_capacity_mwh = plant_capacity.get(fuel, 0) * hours_in_month
            y[fuel] = m.addVar(lb=0, ub=monthly_capacity_mwh, name=f"use_{fuel}_{t}")

    m.update()

    # Constraints
    m.addConstr(sum(y[fuel] for fuel in y) >= demand_df.iloc[t][zone], "Demand_Constraint")
    for fuel in y:
        m.addConstr(y[fuel] <= efficiency[fuel] * x[fuel], f"efficiency_Constraint_{fuel}")
        # Print the added constraint for verification
        print(f"Added constraint: gen_{fuel} <= {efficiency[fuel]} * buy_{fuel}")
    m.update()

    # Objective
    m.setObjective(sum(fuel_prices_df.iloc[t][fuel] * x[fuel] for fuel in x),GRB.MINIMIZE) 
    m.update()

    # Optimize
    m.optimize()

    # print results
    if m.status == GRB.OPTIMAL:
        total_cost = m.objVal
        print(f"Total Cost: EUR {total_cost}")
    else:
        print("No optimal solution found for time step:", t)
        # Exit the loop if no optimal solution is found
        break
    # Store results
    results = pd.concat([results, pd.DataFrame([{
        'Month': demand_df.index[t],
        'Cost_EUR': total_cost,
        'Accumulated_Cost': results['Cost_EUR'].sum() + total_cost,
        'Coal_Bought': x['coal'].X if 'coal' in x else 0,
        'Oil_Bought': x['oil'].X if 'oil' in x else 0,
        'Gas_Bought': x['gas'].X if 'gas' in x else 0,
        'Coal_Generated': y['coal'].X if 'coal' in y else 0,
        'Oil_Generated': y['oil'].X if 'oil' in y else 0,
        'Gas_Generated': y['gas'].X if 'gas' in y else 0
    }])], ignore_index=True)



# Print running cost for each month
print(results)

# Summarize Yearly Cost
total_yearly_cost = results['Accumulated_Cost'].iloc[-1]
print(f"Total Cost for Period: EUR {total_yearly_cost}")
# Out:
# /Users/rofrug/Library/CloudStorage/OneDrive-DanmarksTekniskeUniversitet/First Year PhD/46750 Optimization in modern power systems/46750_g28_Assignment_2/src/data_loader.py:81: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.resample(resample_method).mean()
# PeriodIndex(['2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#              '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12',
#              '2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06',
#              '2021-07', '2021-08', '2021-09', '2021-10', '2021-11', '2021-12',
#              '2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06',
#              '2022-07', '2022-08', '2022-09', '2022-10', '2022-11', '2022-12'],
#             dtype='period[M]', name='utc_timestamp')
# Time step: 0, Date: 2020-01-31 00:00:00
# Hours in month 2020-01: 744
# Hours in month 2020-01: 744
# Hours in month 2020-01: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x36bed635
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 5e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2136854e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.213685434e+07
# Total Cost: EUR 22136854.33579791
# Time step: 1, Date: 2020-02-29 00:00:00
# Hours in month 2020-02: 696
# Hours in month 2020-02: 696
# Hours in month 2020-02: 696
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x671cff78
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7637773e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.763777273e+07
# Total Cost: EUR 17637772.726988096
# Time step: 2, Date: 2020-03-31 00:00:00
# Hours in month 2020-03: 744
# Hours in month 2020-03: 744
# Hours in month 2020-03: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xc272d63e
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6789904e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.678990402e+07
# Total Cost: EUR 16789904.019921027
# Time step: 3, Date: 2020-04-30 00:00:00
# Hours in month 2020-04: 720
# Hours in month 2020-04: 720
# Hours in month 2020-04: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xfd80b749
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9517014e+06   7.169086e+04   0.000000e+00      0s
#        1    1.2096993e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.209699314e+07
# Total Cost: EUR 12096993.143674448
# Time step: 4, Date: 2020-05-31 00:00:00
# Hours in month 2020-05: 744
# Hours in month 2020-05: 744
# Hours in month 2020-05: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xfedca766
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7868276e+06   7.289281e+04   0.000000e+00      0s
#        1    9.3316766e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.331676634e+06
# Total Cost: EUR 9331676.633786058
# Time step: 5, Date: 2020-06-30 00:00:00
# Hours in month 2020-06: 720
# Hours in month 2020-06: 720
# Hours in month 2020-06: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xec4839e1
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0097531e+06   7.169165e+04   0.000000e+00      0s
#        1    1.0068261e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.006826064e+07
# Total Cost: EUR 10068260.637270255
# Time step: 6, Date: 2020-07-31 00:00:00
# Hours in month 2020-07: 744
# Hours in month 2020-07: 744
# Hours in month 2020-07: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x4c45150f
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6658338e+06   7.288702e+04   0.000000e+00      0s
#        1    9.6950253e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.695025289e+06
# Total Cost: EUR 9695025.289109396
# Time step: 7, Date: 2020-08-31 00:00:00
# Hours in month 2020-08: 744
# Hours in month 2020-08: 744
# Hours in month 2020-08: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xb1c31534
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.8644578e+06   7.289745e+04   0.000000e+00      0s
#        1    1.5582968e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.558296848e+07
# Total Cost: EUR 15582968.480647897
# Time step: 8, Date: 2020-09-30 00:00:00
# Hours in month 2020-09: 720
# Hours in month 2020-09: 720
# Hours in month 2020-09: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x24e161b9
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9485079e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.948507904e+07
# Total Cost: EUR 19485079.04196379
# Time step: 9, Date: 2020-10-31 00:00:00
# Hours in month 2020-10: 744
# Hours in month 2020-10: 744
# Hours in month 2020-10: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x3d9d36ef
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5939226e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.593922618e+07
# Total Cost: EUR 25939226.178628437
# Time step: 10, Date: 2020-11-30 00:00:00
# Hours in month 2020-11: 720
# Hours in month 2020-11: 720
# Hours in month 2020-11: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x2b57de69
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5620211e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.562021070e+07
# Total Cost: EUR 25620210.69875151
# Time step: 11, Date: 2020-12-31 00:00:00
# Hours in month 2020-12: 744
# Hours in month 2020-12: 744
# Hours in month 2020-12: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x020cf15d
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [7e+00, 3e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0920775e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.092077539e+07
# Total Cost: EUR 30920775.39043582
# Time step: 12, Date: 2021-01-31 00:00:00
# Hours in month 2021-01: 744
# Hours in month 2021-01: 744
# Hours in month 2021-01: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x3cdc1597
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [8e+00, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.3950964e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  4.395096357e+07
# Total Cost: EUR 43950963.56904355
# Time step: 13, Date: 2021-02-28 00:00:00
# Hours in month 2021-02: 672
# Hours in month 2021-02: 672
# Hours in month 2021-02: 672
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x82466608
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [8e+00, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2661030e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  4.266103004e+07
# Total Cost: EUR 42661030.03915216
# Time step: 14, Date: 2021-03-31 00:00:00
# Hours in month 2021-03: 744
# Hours in month 2021-03: 744
# Hours in month 2021-03: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x73269979
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
# /Users/rofrug/Library/CloudStorage/OneDrive-DanmarksTekniskeUniversitet/First Year PhD/46750 Optimization in modern power systems/46750_g28_Assignment_2/src/data_loader.py:193: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df[selected_col].resample(resample_method).sum()
# /var/folders/8b/6z2b3l6952gg8zq23ybm69hr0000z9/T/ipykernel_20767/3805800542.py:87: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([{
#   Objective range  [8e+00, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3994924e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.399492401e+07
# Total Cost: EUR 33994924.00762477
# Time step: 15, Date: 2021-04-30 00:00:00
# Hours in month 2021-04: 720
# Hours in month 2021-04: 720
# Hours in month 2021-04: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x3741a5aa
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [8e+00, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.5781267e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.578126651e+07
# Total Cost: EUR 35781266.509081535
# Time step: 16, Date: 2021-05-31 00:00:00
# Hours in month 2021-05: 744
# Hours in month 2021-05: 744
# Hours in month 2021-05: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x5a860044
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [1e+01, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.3491399e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  4.349139891e+07
# Total Cost: EUR 43491398.90867807
# Time step: 17, Date: 2021-06-30 00:00:00
# Hours in month 2021-06: 720
# Hours in month 2021-06: 720
# Hours in month 2021-06: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xc7efe190
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [1e+01, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9384933e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  4.938493330e+07
# Total Cost: EUR 49384933.29743907
# Time step: 18, Date: 2021-07-31 00:00:00
# Hours in month 2021-07: 744
# Hours in month 2021-07: 744
# Hours in month 2021-07: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xd77c1f3c
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [1e+01, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.0654482e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  6.065448223e+07
# Total Cost: EUR 60654482.23225091
# Time step: 19, Date: 2021-08-31 00:00:00
# Hours in month 2021-08: 744
# Hours in month 2021-08: 744
# Hours in month 2021-08: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xbbbcba61
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 4e+01]
#   Bounds range     [3e+05, 3e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.5988959e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective
# 29 2022-06-30  1.648474e+08      2.203689e+09  757894.736842       0.000000
# 30 2022-07-31  2.036484e+08      2.407337e+09  783157.894737  864000.000000
# 31 2022-08-31  2.795043e+08      2.686841e+09  783157.894737  864000.000000
# 32 2022-09-30  2.371142e+08      2.923956e+09  757894.736842  864000.000000
# 33 2022-10-31  1.934312e+08      3.117387e+09  783157.894737  864000.000000
# 34 2022-11-30  1.876285e+08      3.305015e+09  757894.736842  864000.000000
# 35 2022-12-31  1.860028e+08      3.491018e+09  783157.894737  864000.000000
#
#       Gas_Bought  Coal_Generated  Oil_Generated  Gas_Generated
# 0   1.550199e+06        297600.0            0.0       852609.6
# 1   1.485773e+06        278400.0            0.0       817175.4
# 2   1.495092e+06        297600.0            0.0       822300.6
# 3   1.570909e+06        115989.6            0.0       864000.0
# 4   1.623273e+06        112407.6            0.0       892800.0
# 5   1.570909e+06        122342.4            0.0       864000.0
# 6   1.623273e+06         66047.4            0.0       892800.0
# 7   1.623273e+06        149554.2            0.0       892800.0
# 8   1.309565e+06        288000.0            0.0       720261.0
# 9   1.471643e+06        297600.0            0.0       809403.6
# 10  1.511829e+06        288000.0            0.0       831505.8
# 11  1.532596e+06        297600.0            0.0       842928.0
# 12  1.623273e+06        297600.0        44643.6       892800.0
# 13  1.466182e+06        268800.0        94059.0       806400.0
# 14  1.590408e+06        297600.0            0.0       874724.4
# 15  1.472731e+06        288000.0            0.0       810001.8
# 16  1.444579e+06        297600.0            0.0       794518.2
# 17  1.378939e+06        288000.0            0.0       758416.2
# 18  1.359875e+06        297600.0            0.0       747931.2
# 19  1.413375e+06        297600.0            0.0       777356.4
# 20  1.443400e+06        288000.0            0.0       793870.2
# 21  9.600982e+05        297600.0       285120.0       528054.0
# 22  1.570909e+06        288000.0        15199.2       864000.0
# 23  1.203221e+06        297600.0       285120.0       661771.8
# 24  1.623273e+06        297600.0        36794.4       892800.0
# 25  1.466182e+06        268800.0        51130.8       806400.0
# 26  1.005984e+06        297600.0       285120.0       553291.2
# 27  1.357324e+06        288000.0            0.0       746528.4
# 28  1.344796e+06        297600.0            0.0       739638.0
# 29  1.270853e+06        288000.0            0.0       698969.4
# 30  6.456796e+05        297600.0       285120.0       355123.8
# 31  7.927233e+05        297600.0       285120.0       435997.8
# 32  7.488305e+05        288000.0       285120.0       411856.8
# 33  8.117967e+05        297600.0       285120.0       446488.2
# 34  9.556942e+05        288000.0       285120.0       525631.8
# 35  9.884095e+05        297600.0       285120.0       543625.2
# Total Cost for Period: EUR 3491018107.3346314

# %%
# plot results
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(demand_df.index, results['Cost_EUR'], marker='o')
plt.title('Model Output: Cost Over Time')
plt.xlabel('Time')
plt.ylabel('Cost (EUR)')
plt.grid()
plt.show()

# %%
# save results to a csv file

results_dir = os.path.join(current_dir.parent, "results/model1")
os.makedirs(results_dir, exist_ok=True)
results.to_csv(os.path.join(results_dir, 'model1_results.csv'), index=False)
