# %%
import os
from pathlib import Path
from gurobipy import Model, GRB
from data_loader import load_prices, load_storage, load_efficiency, load_plant_capacity, load_demand
import pandas as pd

# Data Loading from data folder in the parent directory
current_dir = Path().resolve()
data_folder = os.path.join(current_dir.parent, "data")
fuel_prices_file = os.path.join(data_folder, "fuel_prices.csv")             # Price in EUR/tonne (coal,oil) or EUR/m3 (gas)
storage_file = os.path.join(data_folder, "storage.csv")                     # Max storage in tonnes/m3
efficiency_file = os.path.join(data_folder, "efficiency.csv")               # efficiency of MWh th to MWh el
plant_file = os.path.join(data_folder, "plant_capacity.csv")                # Plant capacity in MWh/month
demand_file = os.path.join(data_folder, "electricity_demand.csv")           # Monthly demand in MWh

start_date = "2019-01"
end_date = "2022-12"
fuels = ["coal", "oil", "gas"]
zone = 'DK_1'  # Specify the zone for demand data
resample_method = 'M' # Monthly resampling 

try:
    fuel_prices_df = load_prices(fuel_prices_file, start_date, end_date, resample_method= resample_method)
    storage = load_storage(storage_file)
    efficiency = load_efficiency(efficiency_file)
    plant_capacity = load_plant_capacity(plant_file)
    demand_df = load_demand(demand_file, start_date, end_date, resample_method= resample_method ,zone=zone ,supply_factor=0.0005)
except Exception as e:
    raise RuntimeError(f"Error loading data: {e}")


# Forloop over each timestep and saving results in df results
results = pd.DataFrame(columns=['Month', 'Cost_EUR','Accumulated_Cost' , 'Coal_Bought', 'Oil_Bought', 'Gas_Bought',
                                   'Coal_Generated', 'Oil_Generated', 'Gas_Generated'])

for t in range(len(demand_df)):
    print(f"Time step: {t}, Date: {demand_df.index[t]}")
    
    # Model Initialization
    m = Model("Fuel_Procurement_OneMonth")

    # Decision Variables
    x = {fuel: m.addVar(lb=0, ub=storage[fuel], name=f"buy_{fuel}") for fuel in fuel_prices_df.columns if fuel in fuels}
    y = {fuel: m.addVar(lb=0, ub=plant_capacity[fuel], name=f"gen_{fuel}") for fuel in fuel_prices_df.columns if fuel in fuels}

    m.update()

    # Constraints
    m.addConstr(sum(y[fuel] for fuel in y) >= demand_df.iloc[t][zone], "Demand_Constraint")
    for fuel in y:
        m.addConstr(y[fuel] <= efficiency[fuel] * x[fuel], f"efficiency_Constraint_{fuel}")
        # Print the added constraint for verification
        print(f"Added constraint: gen_{fuel} <= {efficiency[fuel]} * buy_{fuel}")
    m.update()

    # Objective
    m.setObjective(sum(fuel_prices_df.iloc[t][fuel] * x[fuel] for fuel in x),GRB.MINIMIZE) 
    m.update()

    # Optimize
    m.optimize()

    # print results
    if m.status == GRB.OPTIMAL:
        total_cost = m.objVal
        print(f"Total Cost: EUR {total_cost}")
    else:
        print("No optimal solution found for time step:", t)
        # Exit the loop if no optimal solution is found
        break
    # Store results
    results = pd.concat([results, pd.DataFrame([{
        'Month': demand_df.index[t],
        'Cost_EUR': total_cost,
        'Accumulated_Cost': results['Cost_EUR'].sum() + total_cost,
        'Coal_Bought': x['coal'].X if 'coal' in x else 0,
        'Oil_Bought': x['oil'].X if 'oil' in x else 0,
        'Gas_Bought': x['gas'].X if 'gas' in x else 0,
        'Coal_Generated': y['coal'].X if 'coal' in y else 0,
        'Oil_Generated': y['oil'].X if 'oil' in y else 0,
        'Gas_Generated': y['gas'].X if 'gas' in y else 0
    }])], ignore_index=True)



# Print running cost for each month
print(results)

# Summarize Yearly Cost
total_yearly_cost = results['Accumulated_Cost'].iloc[-1]
print(f"Total Yearly Cost: EUR {total_yearly_cost}")
# Out:
# c:\Users\bjsb\OneDrive - NRGi A S\Gammelt H drev\PhD\Kurser\46750 Optimization in Power Systems\Assignment2group28\46750_g28_Assignment_2\src\data_loader.py:81: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.resample(resample_method).mean()
# Time step: 0, Date: 2019-01-31 00:00:00
# Set parameter Username
# Set parameter LicenseID to value 2728218
# Academic license - for non-commercial use only - expires 2026-10-27
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x798187e1
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [9e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.173049e+02   0.000000e+00      0s
#        1    2.5250032e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.525003201e+04
# Total Cost: EUR 25250.032012500582
# Time step: 1, Date: 2019-02-28 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x12359889
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [9e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.030474e+02   0.000000e+00      0s
#        1    1.8758768e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.875876833e+04
# Total Cost: EUR 18758.768333136857
# Time step: 2, Date: 2019-03-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x950447be
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [8e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.100196e+02   0.000000e+00      0s
#        1    1.9570109e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.957010861e+04
# Total Cost: EUR 19570.108607921637
# Time step: 3, Date: 2019-04-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x21ca09eb
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [7e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.811956e+01   0.000000e+00      0s
#        1    1.3843679e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.384367886e+04
# Total Cost: EUR 13843.678864350706
# Time step: 4, Date: 2019-05-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x29a65f72
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [7e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.032331e+02   0.000000e+00      0s
#        1    1.4717608e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.471760768e+04
# Total Cost: EUR 14717.607684833185
# Time step: 5, Date: 2019-06-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x3e9d2975
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.762763e+01   0.000000e+00      0s
#        1    1.1868129e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.186812937e+04
# Total Cost: EUR 11868.129369618215
# Time step: 6, Date: 2019-07-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xeea1d228
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [7e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.914969e+01   0.000000e+00      0s
#        1    1.3585412e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.358541235e+04
# Total Cost: EUR 13585.412345861048
# Time step: 7, Date: 2019-08-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x61f94d40
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.021233e+02   0.000000e+00      0s
#        1    1.3807671e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.380767146e+04
# Total Cost: EUR 13807.671455571339
# Time step: 8, Date: 2019-09-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xd2783176
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [7e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.010741e+02   0.000000e+00      0s
#        1    1.4554464e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.455446395e+04
# Total Cost: EUR 14554.46394960595
# Time step: 9, Date: 2019-10-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
# c:\Users\bjsb\OneDrive - NRGi A S\Gammelt H drev\PhD\Kurser\46750 Optimization in Power Systems\Assignment2group28\46750_g28_Assignment_2\src\data_loader.py:193: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df[selected_col].resample(resample_method).sum()
# C:\Users\bjsb\AppData\Local\Temp\ipykernel_19976\1089267071.py:72: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([{
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x3ce9d76e
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [7e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.104502e+02   0.000000e+00      0s
#        1    1.6727507e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.672750660e+04
# Total Cost: EUR 16727.50660377798
# Time step: 10, Date: 2019-11-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xfbf0639a
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.144069e+02   0.000000e+00      0s
#        1    1.6794897e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.679489698e+04
# Total Cost: EUR 16794.89697716082
# Time step: 11, Date: 2019-12-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x50cfaeb0
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.165514e+02   0.000000e+00      0s
#        1    1.6383066e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.638306622e+04
# Total Cost: EUR 16383.06621664386
# Time step: 12, Date: 2020-01-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xd13d7655
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 5e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [1e+03, 1e+03]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.198135e+02   0.000000e+00      0s
#        1    1.5630485e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.563048462e+04
# Total Cost: EUR 15630.48462230614
# Time step: 13, Date: 2020-02-29 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x43c3ac79
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.141224e+02   0.000000e+00      0s
#        1    1.3605836e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1
31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x13acc522
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 4e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.119746e+02   0.000000e+00      0s
#        1    4.2955326e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.295532605e+04
# Total Cost: EUR 42955.32605127389
# Time step: 32, Date: 2021-09-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x56e21c1a
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 6e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.126948e+02   0.000000e+00      0s
#        1    5.3800200e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.380020016e+04
# Total Cost: EUR 53800.20015940546
# Time step: 33, Date: 2021-10-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xb187d20d
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [3e+01, 9e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.157056e+02   0.000000e+00      0s
#        1    7.5768626e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  7.576862598e+04
# Total Cost: EUR 75768.62597904663
# Time step: 34, Date: 2021-11-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x00d3d35d
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 8e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [1e+03, 1e+03]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.215833e+02   0.000000e+00      0s
#        1    6.0320534e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.032053448e+04
# Total Cost: EUR 60320.53448083748
# Time step: 35, Date: 2021-12-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x0167eb17
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [1e+03, 1e+03]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.296346e+02   0.000000e+00      0s
#        1    6.8654209e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  6.865420932e+04
# Total Cost: EUR 68654.20932226462
# Time step: 36, Date: 2022-01-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x5fcb209d
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 8e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [1e+03, 1e+03]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.278328e+02   0.000000e+00      0s
#        1    7.0914412e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.091441216e+04
# Total Cost: EUR 70914.41215586883
# Time step: 37, Date: 2022-02-28 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x78b91a9b
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 8e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.173261e+02   0.000000e+00      0s
#        1    6.5965384e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  6.596538444e+04
# Total Cost: EUR 65965.38443964173
# Time step: 38, Date: 2022-03-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xa61c7ce3
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.183345e+02   0.000000e+00      0s
#        1    1.1264277e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.126427696e+05
# Total Cost: EUR 112642.76959807515
# Time step: 39, Date: 2022-04-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xcbe1f82e
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.077634e+02   0.000000e+00      0s
#        1    8.5596668e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.559666771e+04
# Total Cost: EUR 85596.66771239313
# Time step: 40, Date: 2022-05-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x4e22f7aa
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 9e+01]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.080456e+02   0.000000e+00      0s
#        1    8.8221735e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.822173460e+04
# Total Cost: EUR 88221.73460026068
# Time step: 41, Date: 2022-06-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x57b69893
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.028093e+02   0.000000e+00      0s
#        1    8.5362594e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.536259443e+04
# Total Cost: EUR 85362.59443339307
# Time step: 42, Date: 2022-07-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xb7782f72
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.769206e+01   0.000000e+00      0s
#        1    8.9955076e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.995507603e+04
# Total Cost: EUR 89955.07602937648
# Time step: 43, Date: 2022-08-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x2051e712
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.061164e+02   0.000000e+00      0s
#        1    9.5283581e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.528358133e+04
# Total Cost: EUR 95283.58132550781
# Time step: 44, Date: 2022-09-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xde211982
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [8e+02, 8e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.026017e+02   0.000000e+00      0s
#        1    8.6177143e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.617714270e+04
# Total Cost: EUR 86177.14270010988
# Time step: 45, Date: 2022-10-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x5785722c
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.072092e+02   0.000000e+00      0s
#        1    7.7651958e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.765195781e+04
# Total Cost: EUR 77651.95781249648
# Time step: 46, Date: 2022-11-30 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x6408725a
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [4e+02, 5e+03]
#   RHS range        [9e+02, 9e+02]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.144533e+02   0.000000e+00      0s
#        1    7.3960890e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.396088961e+04
# Total Cost: EUR 73960.88960788406
# Time step: 47, Date: 2022-12-31 00:00:00
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1135G7 @ 2.40GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xe4c01364
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [3e+01, 1e+02]
#   Bounds range     
# 42 2022-07-31   89955.076029      1.431011e+06  2056.675000    0.000000
# 43 2022-08-31   95283.581326      1.526295e+06  2105.263158  148.277273
# 44 2022-09-30   86177.142700      1.612472e+06  2105.263158   63.072727
# 45 2022-10-31   77651.957812      1.690124e+06  2105.263158  174.768182
# 46 2022-11-30   73960.889608      1.764085e+06  2105.263158  350.383333
# 47 2022-12-31   83401.552212      1.847486e+06  2105.263158  420.063636
#
#      Gas_Bought  Coal_Generated  Oil_Generated  Gas_Generated
# 0    251.707273        800.0000         0.0000       138.4390
# 1     44.325455        800.0000         0.0000        24.3790
# 2    145.739091        800.0000         0.0000        80.1565
# 3      0.000000        784.9565         0.0000         0.0000
# 4     47.027273        800.0000         0.0000        25.8650
# 5      0.000000        781.0210         0.0000         0.0000
# 6      0.000000        793.1975         0.0000         0.0000
# 7     30.884545        800.0000         0.0000        16.9865
# 8     15.622727        800.0000         0.0000         8.5925
# 9    152.002727        800.0000         0.0000        83.6015
# 10   209.555455        800.0000         0.0000       115.2555
# 11   240.748182        800.0000         0.0000       132.4115
# 12   288.196364        800.0000         0.0000       158.5080
# 13   205.417273        800.0000         0.0000       112.9795
# 14   242.273636        800.0000         0.0000       133.2505
# 15  1484.832727          0.0000         0.0000       816.6580
# 16  1523.041818          0.0000         0.0000       837.6730
# 17  1494.458182          0.0000         0.0000       821.9520
# 18  1452.799091          0.0000         0.0000       799.0395
# 19  1579.324545          0.0000         0.0000       868.6285
# 20    73.122727        800.0000         0.0000        40.2175
# 21   222.732727        800.0000         0.0000       122.5030
# 22   241.675455        800.0000         0.0000       132.9215
# 23   273.527273        800.0000         0.0000       150.4400
# 24   416.732727        800.0000         0.0000       229.2030
# 25   317.059091        800.0000         0.0000       174.3825
# 26   321.703636        800.0000         0.0000       176.9370
# 27   209.093636        800.0000         0.0000       115.0015
# 28   200.179091        800.0000         0.0000       110.0985
# 29   130.933636        800.0000         0.0000        72.0135
# 30   129.592727        800.0000         0.0000        71.2760
# 31   174.176364        800.0000         0.0000        95.7970
# 32   184.651818        800.0000         0.0000       101.5585
# 33     0.000000        800.0000       125.6450         0.0000
# 34   313.938182        800.0000         0.0000       172.6660
# 35     0.000000        800.0000       237.0765         0.0000
# 36   404.840000        800.0000         0.0000       222.6620
# 37   252.016364        800.0000         0.0000       138.6090
# 38     0.000000        800.0000       146.6760         0.0000
# 39   112.921818        800.0000         0.0000        62.1070
# 40   117.027273        800.0000         0.0000        64.3650
# 41    40.862727        800.0000         0.0000        22.4745
# 42     0.000000        781.5365         0.0000         0.0000
# 43     0.000000        800.0000        48.9315         0.0000
# 44     0.000000        800.0000        20.8140         0.0000
# 45     0.000000        800.0000        57.6735         0.0000
# 46     0.000000        800.0000       115.6265         0.0000
# 47     0.000000        800.0000       138.6210         0.0000
# Total Yearly Cost: EUR 1847486.4229341378

# %%
# plot results
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(demand_df.index, results['Cost_EUR'], marker='o')
plt.title('Model Output: Cost Over Time')
plt.xlabel('Time')
plt.ylabel('Cost (EUR)')
plt.grid()
plt.show()

# %%
# save results to a csv file

results_dir = os.path.join(current_dir.parent, "results/model1")
os.makedirs(results_dir, exist_ok=True)
results.to_csv(os.path.join(results_dir, 'model1_results.csv'), index=False)
