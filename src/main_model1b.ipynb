# %%
import os
from pathlib import Path
from gurobipy import Model, GRB
from data_loader import load_prices, load_storage, load_efficiency, load_plant_capacity, load_demand
import pandas as pd

# Data Loading from data folder in the parent directory
current_dir = Path().resolve()
data_folder = os.path.join(current_dir.parent, "data")
fuel_prices_file = os.path.join(data_folder, "fuel_prices.csv")             # Price in EUR/tonne (coal,oil) or EUR/m3 (gas)
storage_file = os.path.join(data_folder, "storage.csv")                     # Max storage in tonnes/m3
efficiency_file = os.path.join(data_folder, "efficiency.csv")               # efficiency of MWh th to MWh el
plant_file = os.path.join(data_folder, "plant_capacity.csv")                # Plant capacity in MWh/month
demand_file = os.path.join(data_folder, "electricity_demand.csv")           # Monthly demand in MWh

start_date = "2020-01"
end_date = "2022-12"
fuels = ["coal", "oil", "gas"]
zone = 'DK_1'  # Specify the zone for demand data
resample_method = 'M' # Monthly resampling 

try:
    fuel_prices_df = load_prices(fuel_prices_file, start_date, end_date, resample_method= resample_method)
    storage = load_storage(storage_file)
    efficiency = load_efficiency(efficiency_file)
    plant_capacity = load_plant_capacity(plant_file)
    demand_df = load_demand(demand_file, start_date, end_date, resample_method= resample_method ,zone=zone ,supply_factor=0.6)
except Exception as e:
    raise RuntimeError(f"Error loading data: {e}")

# periods as Month PeriodIndex (so days_in_month works)
periods = demand_df.index.to_period('M')

print( periods)


# Forloop over each timestep and saving results in df results
results = pd.DataFrame(columns=['Month', 'Cost_EUR','Accumulated_Cost' , 'Coal_Bought', 'Oil_Bought', 'Gas_Bought',
                                   'Coal_Generated', 'Oil_Generated', 'Gas_Generated'])

for t in range(len(demand_df)):
    print(f"Time step: {t}, Date: {demand_df.index[t]}")
    
    # Model Initialization
    m = Model("Fuel_Procurement_OneMonth")

    # Decision Variables
    x = {fuel: m.addVar(lb=0, ub=storage[fuel], name=f"buy_{fuel}") for fuel in fuel_prices_df.columns if fuel in fuels}
    #y = {fuel: m.addVar(lb=0, ub=plant_capacity[fuel], name=f"gen_{fuel}") for fuel in fuel_prices_df.columns if fuel in fuels}    
    
    y = {}
    for fuel in fuels:
                            
            hours_in_month = periods[t].days_in_month * 24

            print(f"Hours in month {periods[t]}: {hours_in_month}")
            # plant_capacity[fuel] is MW -> convert to MWh/month
            monthly_capacity_mwh = plant_capacity.get(fuel, 0) * hours_in_month
            y[fuel] = m.addVar(lb=0, ub=monthly_capacity_mwh, name=f"use_{fuel}_{t}")

    m.update()

    # Constraints
    m.addConstr(sum(y[fuel] for fuel in y) >= demand_df.iloc[t][zone], "Demand_Constraint")
    for fuel in y:
        m.addConstr(y[fuel] <= efficiency[fuel] * x[fuel], f"efficiency_Constraint_{fuel}")
        # Print the added constraint for verification
        print(f"Added constraint: gen_{fuel} <= {efficiency[fuel]} * buy_{fuel}")
    m.update()

    # Objective
    m.setObjective(sum(fuel_prices_df.iloc[t][fuel] * x[fuel] for fuel in x),GRB.MINIMIZE) 
    m.update()

    # Optimize
    m.optimize()

    # print results
    if m.status == GRB.OPTIMAL:
        total_cost = m.objVal
        print(f"Total Cost: EUR {total_cost}")
    else:
        print("No optimal solution found for time step:", t)
        # Exit the loop if no optimal solution is found
        break
    # Store results
    results = pd.concat([results, pd.DataFrame([{
        'Month': demand_df.index[t],
        'Cost_EUR': total_cost,
        'Accumulated_Cost': results['Cost_EUR'].sum() + total_cost,
        'Coal_Bought': x['coal'].X if 'coal' in x else 0,
        'Oil_Bought': x['oil'].X if 'oil' in x else 0,
        'Gas_Bought': x['gas'].X if 'gas' in x else 0,
        'Coal_Generated': y['coal'].X if 'coal' in y else 0,
        'Oil_Generated': y['oil'].X if 'oil' in y else 0,
        'Gas_Generated': y['gas'].X if 'gas' in y else 0
    }])], ignore_index=True)



# Print running cost for each month
print(results)

# Summarize Yearly Cost
total_yearly_cost = results['Accumulated_Cost'].iloc[-1]
print(f"Total Cost for Period: EUR {total_yearly_cost}")
# Out:
# /Users/rofrug/Library/CloudStorage/OneDrive-DanmarksTekniskeUniversitet/First Year PhD/46750 Optimization in modern power systems/46750_g28_Assignment_2/src/data_loader.py:81: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.resample(resample_method).mean()
# PeriodIndex(['2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#              '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12',
#              '2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06',
#              '2021-07', '2021-08', '2021-09', '2021-10', '2021-11', '2021-12',
#              '2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06',
#              '2022-07', '2022-08', '2022-09', '2022-10', '2022-11', '2022-12'],
#             dtype='period[M]', name='utc_timestamp')
# Time step: 0, Date: 2020-01-31 00:00:00
# Set parameter Username
# Set parameter LicenseID to value 2732799
# Academic license - for non-commercial use only - expires 2026-11-04
# Hours in month 2020-01: 744
# Hours in month 2020-01: 744
# Hours in month 2020-01: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x0bc4a1b5
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 5e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2185834e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.218583359e+07
# Total Cost: EUR 22185833.59037085
# Time step: 1, Date: 2020-02-29 00:00:00
# Hours in month 2020-02: 696
# Hours in month 2020-02: 696
# Hours in month 2020-02: 696
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x60e3d1ec
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [6e+00, 4e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7637773e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.763777273e+07
# Total Cost: EUR 17637772.726988096
# Time step: 2, Date: 2020-03-31 00:00:00
# Hours in month 2020-03: 744
# Hours in month 2020-03: 744
# Hours in month 2020-03: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x634c6f16
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 4e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6799682e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.679968246e+07
# Total Cost: EUR 16799682.456799295
# Time step: 3, Date: 2020-04-30 00:00:00
# Hours in month 2020-04: 720
# Hours in month 2020-04: 720
# Hours in month 2020-04: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xcce8027f
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 3e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9166511e+06   7.205050e+04   0.000000e+00      0s
#        1    1.2096993e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.209699314e+07
# Total Cost: EUR 12096993.143674448
# Time step: 4, Date: 2020-05-31 00:00:00
# Hours in month 2020-05: 744
# Hours in month 2020-05: 744
# Hours in month 2020-05: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x30ae52c9
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8470341e+06   1.441080e+05   0.000000e+00      0s
#        1    9.4116833e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.411683343e+06
# Total Cost: EUR 9411683.343455048
# Time step: 5, Date: 2020-06-30 00:00:00
# Hours in month 2020-06: 720
# Hours in month 2020-06: 720
# Hours in month 2020-06: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x1804cd3c
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 3e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9818067e+06   7.205129e+04   0.000000e+00      0s
#        1    1.0068261e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.006826064e+07
# Total Cost: EUR 10068260.637270255
# Time step: 6, Date: 2020-07-31 00:00:00
# Hours in month 2020-07: 744
# Hours in month 2020-07: 744
# Hours in month 2020-07: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x18dd84fe
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [5e+00, 3e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 3 columns, 3 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7313004e+06   1.440964e+05   0.000000e+00      0s
#        1    9.8432422e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.843242183e+06
# Total Cost: EUR 9843242.182752874
# Time step: 7, Date: 2020-08-31 00:00:00
# Hours in month 2020-08: 744
# Hours in month 2020-08: 744
# Hours in month 2020-08: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0
+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.086228289e+08
# Total Cost: EUR 108622828.90872353
# Time step: 21, Date: 2021-10-31 00:00:00
# Hours in month 2021-10: 744
# Hours in month 2021-10: 744
# Hours in month 2021-10: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xb959f4bd
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [3e+01, 9e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5072499e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.507249906e+08
# Total Cost: EUR 150724990.588204
# Time step: 22, Date: 2021-11-30 00:00:00
# Hours in month 2021-11: 720
# Hours in month 2021-11: 720
# Hours in month 2021-11: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xe8bce01c
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 8e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4392670e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.439266989e+08
# Total Cost: EUR 143926698.85818693
# Time step: 23, Date: 2021-12-31 00:00:00
# Hours in month 2021-12: 744
# Hours in month 2021-12: 744
# Hours in month 2021-12: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x5cd0696f
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9613078e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.961307798e+08
# Total Cost: EUR 196130779.75070342
# Time step: 24, Date: 2022-01-31 00:00:00
# Hours in month 2022-01: 744
# Hours in month 2022-01: 744
# Hours in month 2022-01: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x3f37378e
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 8e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5818974e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.581897371e+08
# Total Cost: EUR 158189737.1480092
# Time step: 25, Date: 2022-02-28 00:00:00
# Hours in month 2022-02: 672
# Hours in month 2022-02: 672
# Hours in month 2022-02: 672
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x578e97cb
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [2e+01, 8e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4416610e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.441661017e+08
# Total Cost: EUR 144166101.69287634
# Time step: 26, Date: 2022-03-31 00:00:00
# Hours in month 2022-03: 744
# Hours in month 2022-03: 744
# Hours in month 2022-03: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xa1d0ecf4
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2106105e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.210610535e+08
# Total Cost: EUR 221061053.47205043
# Time step: 27, Date: 2022-04-30 00:00:00
# Hours in month 2022-04: 720
# Hours in month 2022-04: 720
# Hours in month 2022-04: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x74202957
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6417253e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.641725284e+08
# Total Cost: EUR 164172528.384357
# Time step: 28, Date: 2022-05-31 00:00:00
# Hours in month 2022-05: 744
# Hours in month 2022-05: 744
# Hours in month 2022-05: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xb794164b
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 9e+01]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5589258e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.558925786e+08
# /Users/rofrug/Library/CloudStorage/OneDrive-DanmarksTekniskeUniversitet/First Year PhD/46750 Optimization in modern power systems/46750_g28_Assignment_2/src/data_loader.py:193: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df[selected_col].resample(resample_method).sum()
# /var/folders/8b/6z2b3l6952gg8zq23ybm69hr0000z9/T/ipykernel_30293/3805800542.py:87: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([{
# Total Cost: EUR 155892578.63506746
# Time step: 29, Date: 2022-06-30 00:00:00
# Hours in month 2022-06: 720
# Hours in month 2022-06: 720
# Hours in month 2022-06: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x6a64f32d
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6484740e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.648474006e+08
# Total Cost: EUR 164847400.63198364
# Time step: 30, Date: 2022-07-31 00:00:00
# Hours in month 2022-07: 744
# Hours in month 2022-07: 744
# Hours in month 2022-07: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x556c8f60
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [9e+05, 9e+05]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0522103e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.052210256e+08
# Total Cost: EUR 205221025.60676396
# Time step: 31, Date: 2022-08-31 00:00:00
# Hours in month 2022-08: 744
# Hours in month 2022-08: 744
# Hours in month 2022-08: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0x411373cd
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8198880e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.819887955e+08
# Total Cost: EUR 281988795.54733646
# Time step: 32, Date: 2022-09-30 00:00:00
# Hours in month 2022-09: 720
# Hours in month 2022-09: 720
# Hours in month 2022-09: 720
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0xac0e4683
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+00]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [3e+05, 2e+06]
#   RHS range        [1e+06, 1e+06]
# Presolve removed 4 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3663568e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.366356753e+08
# Total Cost: EUR 236635675.29693875
# Time step: 33, Date: 2022-10-31 00:00:00
# Hours in month 2022-10: 744
# Hours in month 2022-10: 744
# Hours in month 2022-10: 744
# Added constraint: gen_coal <= 0.38 * buy_coal
# Added constraint: gen_oil <= 0.33 * buy_oil
# Added constraint: gen_gas <= 0.55 * buy_gas
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.1.0 25B78)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 4 rows, 6 columns and 9 nonzeros
# Model fingerprint: 0
# 27 2022-04-30  1.641725e+08      1.894495e+09  757894.736842       0.000000
# 28 2022-05-31  1.558926e+08      2.050388e+09  757900.000000       0.000000
# 29 2022-06-30  1.648474e+08      2.215235e+09  757894.736842       0.000000
# 30 2022-07-31  2.052210e+08      2.420456e+09  757900.000000  872730.000000
# 31 2022-08-31  2.819888e+08      2.702445e+09  757900.000000  872730.000000
# 32 2022-09-30  2.366357e+08      2.939081e+09  757894.736842  872727.272727
# 33 2022-10-31  1.948963e+08      3.133977e+09  757900.000000  872730.000000
# 34 2022-11-30  1.875807e+08      3.321558e+09  757894.736842  872727.272727
# 35 2022-12-31  1.872149e+08      3.508772e+09  757900.000000  872730.000000
#
#       Gas_Bought  Coal_Generated  Oil_Generated  Gas_Generated
# 0   1.567650e+06        288002.0            0.0       862207.6
# 1   1.485773e+06        278400.0            0.0       817175.4
# 2   1.512543e+06        288002.0            0.0       831898.6
# 3   1.570909e+06        115989.6            0.0       864000.0
# 4   1.571000e+06        141157.6            0.0       864050.0
# 5   1.570909e+06        122342.4            0.0       864000.0
# 6   1.571000e+06         94797.4            0.0       864050.0
# 7   1.571000e+06        178304.2            0.0       864050.0
# 8   1.309565e+06        288000.0            0.0       720261.0
# 9   1.489094e+06        288002.0            0.0       819001.6
# 10  1.511829e+06        288000.0            0.0       831505.8
# 11  1.550047e+06        288002.0            0.0       852526.0
# 12  1.571000e+06        288002.0        82991.6       864050.0
# 13  1.466182e+06        268800.0        94059.0       806400.0
# 14  1.571000e+06        288002.0        20272.4       864050.0
# 15  1.472731e+06        288000.0            0.0       810001.8
# 16  1.462029e+06        288002.0            0.0       804116.2
# 17  1.378939e+06        288000.0            0.0       758416.2
# 18  1.377326e+06        288002.0            0.0       757529.2
# 19  1.430826e+06        288002.0            0.0       786954.4
# 20  1.443400e+06        288000.0            0.0       793870.2
# 21  9.723111e+05        288002.0       288000.9       534771.1
# 22  1.570909e+06        288000.0        15199.2       864000.0
# 23  1.215434e+06        288002.0       288000.9       668488.9
# 24  1.571000e+06        288002.0        75142.4       864050.0
# 25  1.466182e+06        268800.0        51130.8       806400.0
# 26  1.018197e+06        288002.0       288000.9       560008.3
# 27  1.357324e+06        288000.0            0.0       746528.4
# 28  1.362247e+06        288002.0            0.0       749236.0
# 29  1.270853e+06        288000.0            0.0       698969.4
# 30  6.578925e+05        288002.0       288000.9       361840.9
# 31  8.049362e+05        288002.0       288000.9       442714.9
# 32  7.435942e+05        288000.0       288000.0       408976.8
# 33  8.240096e+05        288002.0       288000.9       453205.3
# 34  9.504578e+05        288000.0       288000.0       522751.8
# 35  1.000622e+06        288002.0       288000.9       550342.3
# Total Cost for Period: EUR 3508772481.0752773

# %%
# plot results
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(demand_df.index, results['Cost_EUR'], marker='o')
plt.title('Model Output: Cost Over Time')
plt.xlabel('Time')
plt.ylabel('Cost (EUR)')
plt.grid()
plt.show()

# %%
# save results to a csv file

results_dir = os.path.join(current_dir.parent, "results/model1")
os.makedirs(results_dir, exist_ok=True)
results.to_csv(os.path.join(results_dir, 'model1_results.csv'), index=False)
